# %%
import json
import utilfuncs as uf
import dataloader as dl
import plotmaker as pm

from IPython.display import clear_output

cache_path = 'Data/cache.json'

# %%
# Import Theler into one file
paper_list = {
'Kirby 2009': {
    'tables': [0],
    'tag': 'J/ApJS/191/352',
    'path': 'Temp/Kirby 2009.json',
    'name': 'Kirby 2009',
    'star_header': 'Name',
    'gal_header': 'dSph'
    },
'Duggan 2018': {
    'tables': [1],
    'tag': 'J/ApJ/869/50',
    'path': 'Temp/Duggan 2018.json',
    'name': 'Duggan 2018',
    'star_header': 'Name',
    'gal_header': 'Target'
    },
'Kirby 2015': {
    'tables': [2],
    'tag': 'J/ApJ/801/125',
    'path': 'Temp/Kirby 2015.json',
    'name': 'Kirby 2015',
    'star_header': 'Name',
    'gal_header': 'Syst'
    },
'Skuladottir 2019': {
    'tables': [0],
    'tag': 'J/A+A/631/A171',
    'path': 'Temp/Skuladottir 2019.json',
    'name': 'Skuladottir 2019',
    'star_header': 'Star',
    'gal_header': None,
    'gal_name': 'Scl'
    },
'Theler 2020': {
    'tables': [0, 6, 7, 8],
    'tag': 'J/A+A/642/A176',
    'path': 'Temp/Theler.json',
    'name': 'Theler 2020',
    'star_header': 'ID',
    'gal_header': None,
    'gal_name': 'Sex'
    },
'de los Reyes 2020': {
    'tables': [0],
    'tag': 'J/ApJ/891/85',
    'path': 'Temp/de los Reyes 2020.json',
    'name': 'de los Reyes 2020',
    'star_header': 'ID',
    'gal_header': 'AName'
    },
'Kirby 2017-A':{
    'tables': [1, 2],
    'tag': 'J/ApJ/834/9',
    'path': 'Temp/Kirby 2017-A.json',
    'name': 'Kirby 2017-A',
    'star_header': 'Name',
    'gal_header': 'Gal',
    },
'Kirby 2017':{
    'tables': [0, 1],
    'tag': 'J/ApJ/838/83',
    'path': 'Temp/Kirby 2017.json',
    'name': 'Kirby 2017',
    'star_header': ['__KCS2015_', '__MIC2016_'],
    'gal_header': None,
    'gal_name': 'TriII'
    }
}

test = {'Reichert 2020': {
    'tables': [0, 2],
    'tag': 'J/A+A/641/A127',
    'path': 'Temp/Reichert 2020.json',
    'name': 'Reichert 2020',
    'star_header': 'ID',
    'gal_header': 'Galaxy'
    }}

Kirby_2020 = {'Kirby 2020': {
    'tables': [1],
    'tag': 'J/AJ/159/46',
    'path': 'Temp/Kirby 2020.json',
    'name': 'Kirby 2020',
    'star_header': 'Name',
    'gal_header': 'dSph'
    }
}

# %%
def retrieve_catalog_bulk(paper_tag, tables, paper_name, star_name,
                          gal_title, gal_name = None, save_path = None):
    """Retrieves all tables from the same paper"""
    # Retrieve all tables
    path_list = []
    for table in tables:
        if len(tables) <= 1:
            temp_path = save_path
        else:
            temp_path = save_path.split(".")
            temp_path = f"{temp_path[0]}({table}).{temp_path[1]}"

        path_list.append(temp_path)

        if gal_title is None:
            IsSingleGalaxy = True
        else:
            IsSingleGalaxy = False

        output = dl.retrieve_catalog(paper_tag, temp_path, UI=star_name, gal_title=gal_title,
                            table_num=table, paper_name=paper_name,
                            single_galaxy=IsSingleGalaxy, gal_name = gal_name)
        
        uf.save_to_json(output, temp_path)

    # Merge tables if there are more than one
    if len(path_list) > 1:
        for count, path in enumerate(path_list):
            if count == 0:
                first_table_path = path
            else:
                output = dl.merge_tables(first_table_path, path, paper_name, paper_name,
                                save_path)

    uf.save_to_json(output, save_path)

    # Save the output. If there is only one table, the output was determined earlier
    return output

# %%
_ = dl.merge_tables('Temp/Reichert 2020(0).json', 'Temp/Reichert 2020(2).json', 'Reichert 2020', 'Reichert 2020', 'Temp/Reichert 2020.json')
# Out:
# Done merging Temp/Reichert 2020(2).json into Temp/Reichert 2020(0).json.

# %%
# Add all the papers to the catalog by bulk
for paper in paper_list:
    clear_output(wait=True)
    tag = paper_list[paper]['tag']
    tables = paper_list[paper]['tables']
    path = paper_list[paper]['path']
    name = paper_list[paper]['name']
    star_header = paper_list[paper]['star_header']
    gal_header = paper_list[paper]['gal_header']
    gal_name = paper_list[paper].get('gal_name', None)

    print(f'Retrieving {name}...')
    retrieve_catalog_bulk(tag, tables, name, star_header, gal_header, gal_name, path)
# Out:
# Retrieving Kirby 2017...
# Retrieving catalog J/ApJ/838/83...
# [0] J/ApJ/838/83/table2
# [1] J/ApJ/838/83/table4
# [2] J/ApJ/838/83/table5
# Found the following columns: ['_RAJ2000', '_DEJ2000', '__KCS2015_', '__MIC2016_', 'f__MIC2016_', 'RAJ2000', 'DEJ2000', 'Rad', 'gP1mag', 'e_gP1mag', 'iP1mag', 'e_iP1mag', 'Masks', 'S_N', 'HRV', 'e_HRV', 'sigma', 'Mm', 'f_Mm', 'EW', 'A', 'SimbadName']
# Adding stars...
# Done adding stars.
# Saving catalog to JSON...
# <class 'dict'>
# Done saving catalog.
# Retrieving catalog J/ApJ/838/83...
# [0] J/ApJ/838/83/table2
# [1] J/ApJ/838/83/table4
# [2] J/ApJ/838/83/table5
# Found the following columns: ['__KCS2015_', '__MIC2016_', 'Teff', 'logg', '__Fe_H_CaT', 'e__Fe_H_CaT', '__Fe_H_', 'e__Fe_H_', '__Mg_Fe_', 'e__Mg_Fe_', '__Si_Fe_', 'e__Si_Fe_', '__Ca_Fe_', 'e__Ca_Fe_', '__Ti_Fe_', 'e__Ti_Fe_', '__a_Fe_', 'e__a_Fe_']
# Adding stars...
# Done adding stars.
# Saving catalog to JSON...
# <class 'dict'>
# Done saving catalog.
# Done merging Temp/Kirby 2017(1).json into Temp/Kirby 2017(0).json.
# WARNING: UnitsWarning: Unit 'Sun' not supported by the VOUnit standard. Did you mean uN? [astropy.units.format.vounit]
# e:\Documents and stuff\School_Stuff\AST424\Catalog-Maker\dataloader.py:186: UserWarning: Warning: converting a masked element to nan.
#   star_col = float(star[col])
# WARNING: UnitsWarning: Unit 'Sun' not supported by the VOUnit standard. Did you mean uN? [astropy.units.format.vounit]
# e:\Documents and stuff\School_Stuff\AST424\Catalog-Maker\dataloader.py:186: UserWarning: Warning: converting a masked element to nan.
#   star_col = float(star[col])

# %%
paper_list = Kirby_2020
for paper in paper_list:
    tag = paper_list[paper]['tag']
    tables = paper_list[paper]['tables']
    path = paper_list[paper]['path']
    name = paper_list[paper]['name']
    star_header = paper_list[paper]['star_header']
    gal_header = paper_list[paper]['gal_header']
    gal_name = paper_list[paper].get('gal_name', None)
    
    # clear_output(wait=True)
    print(f'Adding {name}')
    dl.add_catalog(path, name, cache_path, 'Kirby 2009')
# Out:
# Adding Kirby 2020
# Crossmatching galaxies...
# Galaxy AndromedaVII not found in cache.
# Finding the nearest galaxy...
# 507 <class 'dict'> Scl
# 840 <class 'dict'> For
# 840 <class 'dict'> LeoI
# 308 <class 'dict'> Sex
# 277 <class 'dict'> LeoII
# 197 <class 'dict'> CVnI
# 290 <class 'dict'> UMi
# 386 <class 'dict'> Dra
# 59 <class 'dict'> NGC2419
# 50 <class 'dict'> M68
# 105 <class 'dict'> M15
# 9 <class 'dict'> UMaII
# 23 <class 'dict'> M2
# 26 <class 'dict'> M53
# 127 <class 'dict'> LeoA
# 25 <class 'dict'> Aquarius
# 45 <class 'dict'> SagDIG
# 16 <class 'dict'> TriII
# 49 <class 'dict'> Car
# 5 <class 'dict'> BooI
# 34 <class 'dict'> Sgr
# 8 <class 'dict'> RetII
# 3 <class 'dict'> SegI
# Not within the boundary of the nearest galaxy, returning None.
# No galaxy in the cach matches galaxy AndromedaVII. Adding galaxy to cache...
# Done adding AndromedaVII to cache.
#
# Galaxy AndromedaI not found in cache.
# Finding the nearest galaxy...
# 507 <class 'dict'> Scl
# 840 <class 'dict'> For
# 840 <class 'dict'> LeoI
# 308 <class 'dict'> Sex
# 277 <class 'dict'> LeoII
# 197 <class 'dict'> CVnI
# 290 <class 'dict'> UMi
# 386 <class 'dict'> Dra
# 59 <class 'dict'> NGC2419
# 50 <class 'dict'> M68
# 105 <class 'dict'> M15
# 9 <class 'dict'> UMaII
# 23 <class 'dict'> M2
# 26 <class 'dict'> M53
# 127 <class 'dict'> LeoA
# 25 <class 'dict'> Aquarius
# 45 <class 'dict'> SagDIG
# 16 <class 'dict'> TriII
# 49 <class 'dict'> Car
# 5 <class 'dict'> BooI
# 34 <class 'dict'> Sgr
# 8 <class 'dict'> RetII
# 3 <class 'dict'> SegI
# 91 <class 'dict'> AndromedaVII
# Not within the boundary of the nearest galaxy, returning None.
# No galaxy in the cach matches galaxy AndromedaI. Adding galaxy to cache...
# Done adding AndromedaI to cache.
#
# Galaxy AndromedaIII not found in cache.
# Finding the nearest galaxy...
# 507 <class 'dict'> Scl
# 840 <class 'dict'> For
# 840 <class 'dict'> LeoI
# 308 <class 'dict'> Sex
# 277 <class 'dict'> LeoII
# 197 <class 'dict'> CVnI
# 290 <class 'dict'> UMi
# 386 <class 'dict'> Dra
# 59 <class 'dict'> NGC2419
# 50 <class 'dict'> M68
# 105 <class 'dict'> M15
# 9 <class 'dict'> UMaII
# 23 <class 'dict'> M2
# 26 <class 'dict'> M53
# 127 <class 'dict'> LeoA
# 25 <class 'dict'> Aquarius
# 45 <class 'dict'> SagDIG
# 16 <class 'dict'> TriII
# 49 <class 'dict'> Car
# 5 <class 'dict'> BooI
# 34 <class 'dict'> Sgr
# 8 <class 'dict'> RetII
# 3 <class 'dict'> SegI
# 91 <class 'dict'> AndromedaVII
# 28 <class 'dict'> AndromedaI
# Not within the boundary of the nearest galaxy, returning None.
# No galaxy in the cach matches galaxy AndromedaIII. Adding galaxy to cache...
# Done adding AndromedaIII to cache.
#
# Galaxy AndromedaV not found in cache.
# Finding the nearest galaxy...
# 507 <class 'dict'> Scl
# 840 <class 'dict'> For
# 840 <class 'dict'> LeoI
# 308 <class 'dict'> Sex
# 277 <class 'dict'> LeoII
# 197 <class 'dict'> CVnI
# 290 <class 'dict'> UMi
# 386 <class 'dict'> Dra
# 59 <class 'dict'> NGC2419
# 50 <class 'dict'> M68
# 105 <class 'dict'> M15
# 9 <class 'dict'> UMaII
# 23 <class 'dict'> M2
# 26 <class 'dict'> M53
# 127 <class 'dict'> LeoA
# 25 <class 'dict'> Aquarius
# 45 <class 'dict'> SagDIG
# 16 <class 'dict'> TriII
# 49 <class 'dict'> Car
# 5 <class 'dict'> BooI
# 34 <class 'dict'> Sgr
# 8 <class 'dict'> RetII
# 3 <class 'dict'> SegI
# 91 <class 'dict'> AndromedaVII
# 28 <class 'dict'> AndromedaI
# 27 <class 'dict'> AndromedaIII
# Not within the boundary of the nearest galaxy, returning None.
# No galaxy in the cach matches galaxy AndromedaV. Adding galaxy to cache...
# Done adding AndromedaV to cache.
#
# Galaxy AndromedaX not found in cache.
# Finding the nearest galaxy...
# 507 <class 'dict'> Scl
# 840 <class 'dict'> For
# 840 <class 'dict'> LeoI
# 308 <class 'dict'> Sex
# 277 <class 'dict'> LeoII
# 197 <class 'dict'> CVnI
# 290 <class 'dict'> UMi
# 386 <class 'dict'> Dra
# 59 <class 'dict'> NGC2419
# 50 <class 'dict'> M68
# 105 <class 'dict'> M15
# 9 <class 'dict'> UMaII
# 23 <class 'dict'> M2
# 26 <class 'dict'> M53
# 127 <class 'dict'> LeoA
# 25 <class 'dict'> Aquarius
# 45 <class 'dict'> SagDIG
# 16 <class 'dict'> TriII
# 49 <class 'dict'> Car
# 5 <class 'dict'> BooI
# 34 <class 'dict'> Sgr
# 8 <class 'dict'> RetII
# 3 <class 'dict'> SegI
# 91 <class 'dict'> AndromedaVII
# 28 <class 'dict'> AndromedaI
# 27 <class 'dict'> AndromedaIII
# 85 <class 'dict'> AndromedaV
# Not within the boundary of the nearest galaxy, returning None.
# No galaxy in the cach matches galaxy AndromedaX. Adding galaxy to cache...
# Done adding AndromedaX to cache.
#
# 507 <class 'dict'> Scl
# 840 <class 'dict'> For
# 840 <class 'dict'> LeoI
# 308 <class 'dict'> Sex
# 277 <class 'dict'> LeoII
# 197 <class 'dict'> CVnI
# 290 <class 'dict'> UMi
# 386 <class 'dict'> Dra
# 59 <class 'dict'> NGC2419
# 50 <class 'dict'> M68
# 105 <class 'dict'> M15
# 9 <class 'dict'> UMaII
# 23 <class 'dict'> M2
# 26 <class 'dict'> M53
# 127 <class 'dict'> LeoA
# 25 <class 'dict'> Aquarius
# 45 <class 'dict'> SagDIG
# 16 <class 'dict'> TriII
# 49 <class 'dict'> Car
# 5 <class 'dict'> BooI
# 34 <class 'dict'> Sgr
# 8 <class 'dict'> RetII
# 3 <class 'dict'> SegI
# 91 <class 'dict'> AndromedaVII
# 28 <class 'dict'> AndromedaI
# 27 <class 'dict'> AndromedaIII
# 85 <class 'dict'> AndromedaV
# 25 <class 'dict'> AndromedaX
# The updated cache has 28 galaxies and 4485 starsfrom 10 catalogs.
# Saving cache...
# Added Kirby 2020 to cache.
